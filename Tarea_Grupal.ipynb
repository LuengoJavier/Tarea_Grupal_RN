# %% [markdown]
# # Tarea Grupal Redes Neuronales

# %% [markdown]
# ### Función de carga de datos desde el directorio FER

# %%
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization
from tensorflow.keras.layers import MaxPooling2D, AveragePooling2D, add
from tensorflow.keras.layers import Input, Flatten, Dropout
from tensorflow.keras.layers import concatenate, Activation
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import os
import numpy as np
import math
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image


def extraer_imagenes(directorio):
    imagenes_train, clases_train = [], []
    imagenes_test, clases_test = [], []

    for tipo_datos in ['train', 'test']:
        ruta_tipo = os.path.join(directorio, tipo_datos)
        clases = sorted(os.listdir(ruta_tipo))  # Asegura orden consistente de clases

        for idx, clase in enumerate(clases):
            ruta_clase = os.path.join(ruta_tipo, clase)
            for foto in os.listdir(ruta_clase):
                ruta_foto = os.path.join(ruta_clase, foto)
                try:
                    img = image.load_img(ruta_foto, target_size=(48, 48), color_mode='grayscale')
                    img_array = np.array(img)

                    if tipo_datos == 'train':
                        imagenes_train.append(img_array)
                        clases_train.append(idx)
                    else:
                        imagenes_test.append(img_array)
                        clases_test.append(idx)
                except Exception as e:
                    print(f"Error al cargar {ruta_foto}: {e}")

    # Convertir a arrays y normalizar
    X_train = np.expand_dims(np.array(imagenes_train, dtype=np.float32) / 255.0, axis=-1)
    X_test = np.expand_dims(np.array(imagenes_test, dtype=np.float32) / 255.0, axis=-1)
    y_train = to_categorical(clases_train)
    y_test = to_categorical(clases_test)

    return X_train, X_test, y_train, y_test

# %% [markdown]
# ### Definicón de parámertros y arquitectura, además de cargar los datos del directorio
# -   Para cumplir con lo pedido en el punto a de la pregunta 1, se diseñaron 3 archivos.py, que ejecutarán el modelo con los factores de compresión solicitados (0.3, 0.5, 0.7), Los archivos se llaman de la siguiente manera:
#
#     - Punto_a_1.py = factor compresión 0.3
#     - Punto_a_2.py = factor compresión 0.5
#     - Punto_a_3.py = factor compresión 0.7

# %%
# training parameters
batch_size = 32
#epochs = 200
epochs = 200
data_augmentation = True

# network parameters
num_classes = 7
num_dense_blocks = 4
use_max_pool = False

growth_rate = 12
depth = 100
num_bottleneck_layers = (depth - 4) // (2 * num_dense_blocks)

num_filters_bef_dense_block = 2 * growth_rate
compression_factor = 0.5

# load the CIFAR10 data
# Cargar los datos de CIFAR10.
x_train, x_test, y_train, y_test = extraer_imagenes("FER")
# input image dimensions
input_shape = x_train.shape[1:]

# mormalize data
print('x_train shape:', x_train.shape)
print('y_train shape:', y_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices.


def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr
# Out:
# x_train shape: (28709, 48, 48, 1)
# y_train shape: (28709, 7)
# 28709 train samples
# 7178 test samples

# %% [markdown]
# ### Se diseña el modelo DenseNet

# %%
# start model definition
# densenet CNNs (composite function) are made of BN-ReLU-Conv2D
inputs = Input(shape=input_shape)
x = BatchNormalization()(inputs)
x = Activation('relu')(x)
x = Conv2D(num_filters_bef_dense_block,kernel_size=3,padding='same',kernel_initializer='he_normal')(x)
x = concatenate([inputs, x])

# stack of dense blocks bridged by transition layers
for i in range(num_dense_blocks):
    # a dense block is a stack of bottleneck layers
    for j in range(num_bottleneck_layers):
        y = BatchNormalization()(x)
        y = Activation('relu')(y)
        y = Conv2D(4 * growth_rate,kernel_size=1,padding='same',kernel_initializer='he_normal')(y)
        if not data_augmentation:
            y = Dropout(0.2)(y)
        y = BatchNormalization()(y)
        y = Activation('relu')(y)
        y = Conv2D(growth_rate,kernel_size=3,padding='same',kernel_initializer='he_normal')(y)
        if not data_augmentation:
            y = Dropout(0.2)(y)
        x = concatenate([x, y])

    # no transition layer after the last dense block
    if i == num_dense_blocks - 1:
        continue

    # transition layer compresses num of feature maps and reduces the size by 2
    num_filters_bef_dense_block += num_bottleneck_layers * growth_rate
    num_filters_bef_dense_block = int(num_filters_bef_dense_block * compression_factor)
    y = BatchNormalization()(x)
    y = Conv2D(num_filters_bef_dense_block,kernel_size=1,padding='same',kernel_initializer='he_normal')(y)
    if not data_augmentation:
        y = Dropout(0.2)(y)
    x = AveragePooling2D()(y)


# add classifier on top
# after average pooling, size of feature map is 1 x 1
x = AveragePooling2D(pool_size=4)(x)
y = Flatten()(x)
outputs = Dense(num_classes,kernel_initializer='he_normal',activation='softmax')(y)

# instantiate and compile model
# orig paper uses SGD but RMSprop works better for DenseNet
model = Model(inputs=inputs, outputs=outputs)
model.compile(loss='categorical_crossentropy',optimizer=RMSprop(1e-3),metrics=['acc'])
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 48, 48, 1)]  0           []
#
#  batch_normalization_200 (Batch  (None, 48, 48, 1)   4           ['input_3[0][0]']
#  Normalization)
#
#  activation_194 (Activation)    (None, 48, 48, 1)    0           ['batch_normalization_200[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 48, 48, 24)   240         ['activation_194[0][0]']
#
#  concatenate_98 (Concatenate)   (None, 48, 48, 25)   0           ['input_3[0][0]',
#                                                                   'conv2d_200[0][0]']
#
#  batch_normalization_201 (Batch  (None, 48, 48, 25)  100         ['concatenate_98[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 48, 48, 25)   0           ['batch_normalization_201[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 48, 48, 48)   1248        ['activation_195[0][0]']
#
#  batch_normalization_202 (Batch  (None, 48, 48, 48)  192         ['conv2d_201[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 48, 48, 48)   0           ['batch_normalization_202[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 48, 48, 12)   5196        ['activation_196[0][0]']
#
#  concatenate_99 (Concatenate)   (None, 48, 48, 37)   0           ['concatenate_98[0][0]',
#                                                                   'conv2d_202[0][0]']
#
#  batch_normalization_203 (Batch  (None, 48, 48, 37)  148         ['concatenate_99[0][0]']
#  Normalization)
#
#  activation_197 (Activation)    (None, 48, 48, 37)   0           ['batch_normalization_203[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 48, 48, 48)   1824        ['activation_197[0][0]']
#
#  batch_normalization_204 (Batch  (None, 48, 48, 48)  192         ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_198 (Activation)    (None, 48, 48, 48)   0           ['batch_normalization_204[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 48, 48, 12)   5196        ['activation_198[0][0]']
#
#  concatenate_100 (Concatenate)  (None, 48, 48, 49)   0           ['concatenate_99[0][0]',
#                                                                   'conv2d_204[0][0]']
#
#  batch_normalization_205 (Batch  (None, 48, 48, 49)  196         ['concatenate_100[0][0]']
#  Normalization)
#
#  activation_199 (Activation)    (None, 48, 48, 49)   0           ['batch_normalization_205[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 48, 48, 48)   2400        ['activation_199[0][0]']
#
#  batch_normalization_206 (Batch  (None, 48, 48, 48)  192         ['conv2d_205[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 48, 48, 48)   0           ['batch_normalization_206[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 48, 48, 12)   5196        ['activation_200[0][0]']
#
#  concatenate_101 (Concatenate)  (None, 48, 48, 61)   0           ['concatenate_100[0][0]',
#                                                                   'conv2d_206[0][0]']
#
#  batch_normalization_207 (Batch  (None, 48, 48, 61)  244         ['concatenate_101[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 48, 48, 61)   0           ['batch_normalization_207[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 48, 48, 48)   2976        ['activation_201[0][0]']
#
#  batch_normalization_208 (Batch  (None, 48, 48, 48)  192         ['conv2d_207[0][0]']
#  Normalization)
#
#  activation_202 (Activation)    (None, 48, 48, 48)   0           ['batch_normalization_208[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 48, 48, 12)   5196        ['activation_202[0][0]']
#
#  concatenate_102 (Concatenate)  (None, 48, 48, 73)   0           ['concatenate_101[0][0]',
#                                                                   'conv2d_208[0][0]']
#
#  batch_normalization_209 (Batch  (None, 48, 48, 73)  292         ['concatenate_102[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 48, 48, 73)   0           ['batch_normalization_209[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 48, 48, 48)   3552        ['activation_203[0][0]']
#
#  batch_normalization_210 (Batch  (None, 48, 48, 48)  192         ['conv2d_209[0][0]']
#  Normalization)
#
#  activation_204 (Activation)    (None, 48, 48, 48)   0           ['batch_normalization_210[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 48, 48, 12)   5196        ['activation_204[0][0]']
#
#  concatenate_103 (Concatenate)  (None, 48, 48, 85)   0           ['concatenate_102[0][0]',
#                                                                   'conv2d_210[0][0]']
#
#  batch_normalization_211 (Batch  (None, 48, 48, 85)  340         ['concatenate_103[0][0]']
#  Normalization)
#
#  activation_205 (Activation)    (None, 48, 48, 85)   0           ['batch_normalization_211[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 48, 48, 48)   4128        ['activation_205[0][0]']
#
#  batch_normalization_212 (Batch  (None, 48, 48, 48)  192         ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_206 (Activation)    (None, 48, 48, 48)   0           ['batch_normalization_212[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 48, 48, 12)   5196        ['activation_206[0][0]']
#
#  concatenate_104 (Concatenate)  (None, 48, 48, 97)   0           ['concatenate_103[0][0]',
#                                                                   'conv2d_212[0][0]']
#
#  batch_normalization_213 (Batch  (None, 48, 48, 97)  388         ['concatenate_104[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 48, 48, 97)   0           ['batch_normalization_213[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 48, 48, 48)   4704        ['activation_207[0][0]']
#
#  batch_normalization_214 (Batch  (None, 48, 48, 48)  192         ['conv2d_213[0][0]']
#  Normalization)
#
#  activation_208 (Activation)    (None, 48, 48, 48)   0           ['batch_normalization_214[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 48, 48, 12)   5196        ['activation_208[0][0]']
#
#  concatenate_105 (Concatenate)  (None, 48, 48, 109)  0           ['concatenate_104[0][0]',
#                                                                   'conv2d_214[0][0]']
#
#  batch_normalization_215 (Batch  (None, 48, 48, 109)  436        ['concatenate_105[0][0]']
#  Normalization)
#
#  activation_209 (Activation)    (None, 48, 48, 109)  0           ['batch_normalization_215[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 48, 48, 48)   5280        ['activation_209[0][0]']
#
#  batch_normalization_216 (Batch  (None, 48, 48, 48)  192         ['conv2d_215[0][0]']
#  Normalization)
#
#  activation_210 (Activation)    (None, 48, 48, 48)   0           ['batch_normalization_216[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 48, 48, 12)   5196        ['activation_210[0][0]']
#
#  concatenate_106 (Concatenate)  (None, 48, 48, 121)  0           ['concatenate_105[0][0]',
#                                                                   'conv2d_216[0][0]']
#
#  batch_normalization_217 (Batch  (None, 48, 48, 121)  484        ['concatenate_106[0][0]']
#  Normalization)
#
#  activation_211 (Activation)    (None, 48, 48, 121)  0           ['batch_normalization_217[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 48, 48, 48)   5856        ['activation_211[0][0]']
#
#  batch_normalization_218 (Batch  (None, 48, 48, 48)  192         ['conv2d_217[0][0]']
#  Normalization)
#
#  activation_212 (Activation)    (None, 48, 48, 48)   0           ['batch_normalization_218[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 48, 48, 12)   5196        ['activation_212[0][0]']
#
#  concatenate_107 (Concatenate)  (None, 48, 48, 133)  0           ['concatenate_106[0][0]',
#                                                                   'conv2d_218[0][0]']
#
#  batch_normalization_219 (Batch  (None, 48, 48, 133)  532        ['concatenate_107[0][0]']
#  Normalization)
#
#  activation_213 (Activation)    (None, 48, 48, 133)  0           ['batch_normalization_219[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 48, 48, 48)   6432        ['activation_213[0][0]']
#
#  batch_normalization_220 (Batch  (None, 48, 48, 48)  192         ['conv2d_219[0][0]']
#  Normalization)
#
#  activation_214 (Activation)    (None, 48, 48, 48)   0           ['batch_normalization_220[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 48, 48, 12)   5196        ['activation_214[0][0]']
#
#  concatenate_108 (Concatenate)  (None, 48, 48, 145)  0           ['concatenate_107[0][0]',
#                                                                   'conv2d_220[0][0]']
#
#  batch_normalization_221 (Batch  (None, 48, 48, 145)  580        ['concatenate_108[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (None, 48, 48, 145)  0           ['batch_normalization_221[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 48, 48, 48)   7008        ['activation_215[0][0]']
#
#  batch_normalization_222 (Batch  (None, 48, 48, 48)  192         ['conv2d_221[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 48, 48, 48)   0           ['batch_normalization_222[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 48, 48, 12)   5196        ['activation_216[0][0]']
#
#  concatenate_109 (Concatenate)  (None, 48, 48, 157)  0           ['concatenate_108[0][0]',
#                                                                   'conv2d_222[0][0]']
#
#  batch_normalization_223 (Batch  (None, 48, 48, 157)  628        ['concatenate_109[0][0]']
#  Normalization)
#
#  activation_217 (Activation)    (None, 48, 48, 157)  0           ['batch_normalization_223[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 48, 48, 48)   7584        ['activation_217[0][0]']
#
#  batch_normalization_224 (Batch  (None, 48, 48, 48)  192         ['conv2d_223[0][0]']
#  Normalization)
#
#  activation_218 (Activation)    (None, 48, 48, 48)   0           ['batch_normalization_224[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 48, 48, 12)   5196        ['activation_218[0][0]']
#
#  concatenate_110 (Concatenate)  (None, 48, 48, 169)  0           ['concatenate_109[0][0]',
#                                                                   'conv2d_224[0][0]']
#
#  batch_normalization_225 (Batch  (None, 48, 48, 169)  676        ['concatenate_110[0][0]']
#  Normalization)
#
#  conv2d_225 (Conv2D)            (None, 48, 48, 84)   14280       ['batch_normalization_225[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 24, 24, 84)  0           ['conv2d_225[0][0]']
#  oling2D)
#
#  batch_normalization_226 (Batch  (None, 24, 24, 84)  336         ['average_pooling2d_8[0][0]']
#  Normalization)
#
#  activation_219 (Activation)    (None, 24, 24, 84)   0           ['batch_normalization_226[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 24, 24, 48)   4080        ['activation_219[0][0]']
#
#  batch_normalization_227 (Batch  (None, 24, 24, 48)  192         ['conv2d_226[0][0]']
#  Normalization)
#
#  activation_220 (Activation)    (None, 24, 24, 48)   0           ['batch_normalization_227[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 24, 24, 12)   5196        ['activation_220[0][0]']
#
#  concatenate_111 (Concatenate)  (None, 24, 24, 96)   0           ['average_pooling2d_8[0][0]',
#                                                                   'conv2d_227[0][0]']
#
#  batch_normalization_228 (Batch  (None, 24, 24, 96)  384         ['concatenate_111[0][0]']
#  Normalization)
#
#  activation_221 (Activation)    (None, 24, 24, 96)   0           ['batch_normalization_228[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 24, 24, 48)   4656        ['activation_221[0][0]']
#
#  batch_normalization_229 (Batch  (None, 24, 24, 48)  192         ['conv2d_228[0][0]']
#  Normalization)
#
#  activation_222 (Activation)    (None, 24, 24, 48)   0           ['batch_normalization_229[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 24, 24, 12)   5196        ['activation_222[0][0]']
#
#  concatenate_112 (Concatenate)  (None, 24, 24, 108)  0           ['concatenate_111[0][0]',
#                                                                   'conv2d_229[0][0]']
#
#  batch_normalization_230 (Batch  (None, 24, 24, 108)  432        ['concatenate_112[0][0]']
#  Normalization)
#
#  activation_223 (Activation)    (None, 24, 24, 108)  0           ['batch_normalization_230[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 24, 24, 48)   5232        ['activation_223[0][0]']
#
#  batch_normalization_231 (Batch  (None, 24, 24, 48)  192         ['conv2d_230[0][0]']
#  Normalization)
#
#  activation_224 (Activation)    (None, 24, 24, 48)   0           ['batch_normalization_231[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 24, 24, 12)   5196        ['activation_224[0][0]']
#
#  concatenate_113 (Concatenate)  (None, 24, 24, 120)  0           ['concatenate_112[0][0]',
#                                                                   'conv2d_231[0][0]']
#
#  batch_normalization_232 (Batch  (None, 24, 24, 120)  480        ['concatenate_113[0][0]']
#  Normalization)
#
#  activation_225 (Activation)    (None, 24, 24, 120)  0           ['batch_normalization_232[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 24, 24, 48)   5808        ['activation_225[0][0]']
#
#  batch_normalization_233 (Batch  (None, 24, 24, 48)  192         ['conv2d_232[0][0]']
#  Normalization)
#
#  activation_226 (Activation)    (None, 24, 24, 48)   0           ['batch_normalization_233[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 24, 24, 12)   5196        ['activation_226[0][0]']
#
#  concatenate_114 (Concatenate)  (None, 24, 24, 132)  0           ['concatenate_113[0][0]',
#                                                                   'conv2d_233[0][0]']
#
#  batch_normalization_234 (Batch  (None, 24, 24, 132)  528        ['concatenate_114[0][0]']
#  Normalization)
#
#  activation_227 (Activation)    (None, 24, 24, 132)  0           ['batch_normalization_234[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 24, 24, 48)   6384        ['activation_227[0][0]']
#
#  batch_normalization_235 (Batch  (None, 24, 24, 48)  192         ['conv2d_234[0][0]']
#  Normalization)
#
#  activation_228 (Activation)    (None, 24, 24, 48)   0           ['batch_normalization_235[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 24, 24, 12)   5196        ['activation_228[0][0]']
#
#  concatenate_115 (Concatenate)  (None, 24, 24, 144)  0           ['concatenate_114[0][0]',
#                                                                   'conv2d_235[0][0]']
#
#  batch_normalization_236 (Batch  (None, 24, 24, 144)  576        ['concatenate_115[0][0]']
#  Normalization)
#
#  activation_229 (Activation)    (None, 24, 24, 144)  0           ['batch_normalization_236[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 24, 24, 48)   6960        ['activation_229[0][0]']
#
#  batch_normalization_237 (Batch  (None, 24, 24, 48)  192         ['conv2d_236[0][0]']
#  Normalization)
#
#  activation_230 (Activation)    (None, 24, 24, 48)   0           ['batch_normalization_237[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 24, 24, 12)   5196        ['activation_230[0][0]']
#
#  concatenate_116 (Concatenate)  (None, 24, 24, 156)  0           ['concatenate_115[0][0]',
#                                                                   'conv2d_237[0][0]']
#
#  batch_normalization_238 (Batch  (None, 24, 24, 156)  624        ['concatenate_116[0][0]']
#  Normalization)
#
#  activation_231 (Activation)    (None, 24, 24, 156)  0           ['batch_normalization_238[0][0]']
#
#  conv2d_238 (Conv2D)            (None, 24, 24, 48)   7536        ['activation_231[0][0]']
#
#  batch_normalization_239 (Batch  (None, 24, 24, 48)  192         ['conv2d_238[0][0]']
#  Normalization)
#
#  activation_232 (Activation)    (None, 24, 24, 48)   0           ['batch_normalization_239[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 24, 24, 12)   5196        ['activation_232[0][0]']
#
#  concatenate_117 (Concatenate)  (None, 24, 24, 168)  0           ['concatenate_116[0][0]',
#                                                                   'conv2d_239[0][0]']
#
#  batch_normalization_240 (Batch  (None, 24, 24, 168)  672        ['concatenate_117[0][0]']
#  Normalization)
#
#  activation_233 (Activation)    (None, 24, 24, 168)  0           ['batch_normalization_240[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 24, 24, 48)   8112        ['activation_233[0][0]']
#
#  batch_normalization_241 (Batch  (None, 24, 24, 48)  192         ['conv2d_240[0][0]']
#  Normalization)
#
#  activation_234 (Activation)    (None, 24, 24, 48)   0           ['batch_normalization_241[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 24, 24, 12)   5196        ['activation_234[0][0]']
#
#  concatenate_118 (Concatenate)  (None, 24, 24, 180)  0           ['concatenate_117[0][0]',
#                                                                   'conv2d_241[0][0]']
#
#  batch_normalization_242 (Batch  (None, 24, 24, 180)  720        ['concatenate_118[0][0]']
#  Normalization)
#
#  activation_235 (Activation)    (None, 24, 24, 180)  0           ['batch_normalization_242[0][0]']
#
#  conv2d_242 (Conv2D)            (None, 24, 24, 48)   8688        ['activation_235[0][0]']
#
#  batch_normalization_243 (Batch  (None, 24, 24, 48)  192         ['conv2d_242[0][0]']
#  Normalization)
#
#  activation_236 (Activation)    (None, 24, 24, 48)   0           ['batch_normalization_243[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 24, 24, 12)   5196        ['activation_236[0][0]']
#
#  concatenate_119 (Concatenate)  (None, 24, 24, 192)  0           ['concatenate_118[0][0]',
#                                                                   'conv2d_243[0][0]']
#
#  batch_normalization_244 (Batch  (None, 24, 24, 192)  768        ['concatenate_119[0][0]']
#  Normalization)
#
#  activation_237 (Activation)    (None, 24, 24, 192)  0           ['batch_normalization_244[0][0]']
#
#  conv2d_244 (Conv2D)            (None, 24, 24, 48)   9264        ['activation_237[0][0]']
#
#  batch_normalization_245 (Batch  (None, 24, 24, 48)  192         ['conv2d_244[0][0]']
#  Normalization)
#
#  activation_238 (Activation)    (None, 24, 24, 48)   0           ['batch_normalization_245[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 24, 24, 12)   5196        ['activation_238[0][0]']
#
#  concatenate_120 (Concatenate)  (None, 24, 24, 204)  0           ['concatenate_119[0][0]',
#                                                                   'conv2d_245[0][0]']
#
#  batch_normalization_246 (Batch  (None, 24, 24, 204)  816        ['concatenate_120[0][0]']
#  Normalization)
#
#  activation_239 (Activation)    (None, 24, 24, 204)  0           ['batch_normalization_246[0][0]']
#
#  conv2d_246 (Conv2D)            (None, 24, 24, 48)   9840        ['activation_239[0][0]']
#
#  batch_normalization_247 (Batch  (None, 24, 24, 48)  192         ['conv2d_246[0][0]']
#  Normalization)
#
#  activation_240 (Activation)    (None, 24, 24, 48)   0           ['batch_normalization_247[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 24, 24, 12)   5196        ['activation_240[0][0]']
#
#  concatenate_121 (Concatenate)  (None, 24, 24, 216)  0           ['concatenate_120[0][0]',
#                                                                   'conv2d_247[0][0]']
#
#  batch_normalization_248 (Batch  (None, 24, 24, 216)  864        ['concatenate_121[0][0]']
#  Normalization)
#
#  activation_241 (Activation)    (None, 24, 24, 216)  0           ['batch_normalization_248[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 24, 24, 48)   10416       ['activation_241[0][0]']
#
#  batch_normalization_249 (Batch  (None, 24, 24, 48)  192         ['conv2d_248[0][0]']
#  Normalization)
#
#  activation_242 (Activation)    (None, 24, 24, 48)   0           ['batch_normalization_249[0][0]']
#
#  conv2d_249 (Conv2D)            (None, 24, 24, 12)   5196        ['activation_242[0][0]']
#
#  concatenate_122 (Concatenate)  (None, 24, 24, 228)  0           ['concatenate_121[0][0]',
#                                                                   'conv2d_249[0][0]']
#
#  batch_normalization_250 (Batch  (None, 24, 24, 228)  912        ['concatenate_122[0][0]']
#  Normalization)
#
#  conv2d_250 (Conv2D)            (None, 24, 24, 114)  26106       ['batch_normalization_250[0][0]']
#
#  average_pooling2d_9 (AveragePo  (None, 12, 12, 114)  0          ['conv2d_250[0][0]']
#  oling2D)
#
#  batch_normalization_251 (Batch  (None, 12, 12, 114)  456        ['average_pooling2d_9[0][0]']
#  Normalization)
#
#  activation_243 (Activation)    (None, 12, 12, 114)  0           ['batch_normalization_251[0][0]']
#
#  conv2d_251 (Conv2D)            (None, 12, 12, 48)   5520        ['activation_243[0][0]']
#
#  batch_normalization_252 (Batch  (None, 12, 12, 48)  192         ['conv2d_251[0][0]']
#  Normalization)
#
#  activation_244 (Activation)    (None, 12, 12, 48)   0           ['batch_normalization_252[0][0]']
#
#  conv2d_252 (Conv2D)            (None, 12, 12, 12)   5196        ['activation_244[0][0]']
#
#  concatenate_123 (Concatenate)  (None, 12, 12, 126)  0           ['average_pooling2d_9[0][0]',
#                                                                   'conv2d_252[0][0]']
#
#  batch_normalization_253 (Batch  (None, 12, 12, 126)  504        ['concatenate_123[0][0]']
#  Normalization)
#
#  activation_245 (Activation)    (None, 12, 12, 126)  0           ['batch_normalization_253[0][0]']
#
#  conv2d_253 (Conv2D)            (None, 12, 12, 48)   6096        ['activation_245[0][0]']
#
#  batch_normalization_254 (Batch  (None, 12, 12, 48)  192         ['conv2d_253[0][0]']
#  Normalization)
#
#  activation_246 (Activation)    (None, 12, 12, 48)   0           ['batch_normalization_254[0][0]']
#
#  conv2d_254 (Conv2D)            (None, 12, 12, 12)   5196        ['activation_246[0][0]']
#
#  concatenate_124 (Concatenate)  (None, 12, 12, 138)  0           ['concatenate_123[0][0]',
#                                                                   'conv2d_254[0][0]']
#
#  batch_normalization_255 (Batch  (None, 12, 12, 138)  552        ['concatenate_124[0][0]']
#  Normalization)
#
#  activation_247 (Activation)    (None, 12, 12, 138)  0           ['batch_normalization_255[0][0]']
#
#  conv2d_255 (Conv2D)            (None, 12, 12, 48)   6672        ['activation_247[0][0]']
#
#  batch_normalization_256 (Batch  (None, 12, 12, 48)  192         ['conv2d_255[0][0]']
#  Normalization)
#
#  activation_248 (Activation)    (None, 12, 12, 48)   0           ['batch_normalization_256[0][0]']
# ...
#
#  activation_273 (Activation)    (None, 6, 6, 165)    0           ['batch_normalization_282[0][0]']
#
#  conv2d_282 (Conv2D)            (None, 6, 6, 48)     7968        ['activation_273[0][0]']
#
#  batch_normalization_283 (Batch  (None, 6, 6, 48)    192         ['conv2d_282[0][0]']
#  Normalization)
#
#  activation_274 (Activation)    (None, 6, 6, 48)     0           ['batch_normalization_283[0][0]']
#
#  conv2d_283 (Conv2D)            (None, 6, 6, 12)     5196        ['activation_274[0][0]']
#
#  concatenate_138 (Concatenate)  (None, 6, 6, 177)    0           ['concatenate_137[0][0]',
#                                                                   'conv2d_283[0][0]']
#
#  batch_normalization_284 (Batch  (None, 6, 6, 177)   708         ['concatenate_138[0][0]']
#  Normalization)
#
#  activation_275 (Activation)    (None, 6, 6, 177)    0           ['batch_normalization_284[0][0]']
#
#  conv2d_284 (Conv2D)            (None, 6, 6, 48)     8544        ['activation_275[0][0]']
#
#  batch_normalization_285 (Batch  (None, 6, 6, 48)    192         ['conv2d_284[0][0]']
#  Normalization)
#
#  activation_276 (Activation)    (None, 6, 6, 48)     0           ['batch_normalization_285[0][0]']
#
#  conv2d_285 (Conv2D)            (None, 6, 6, 12)     5196        ['activation_276[0][0]']
#
#  concatenate_139 (Concatenate)  (None, 6, 6, 189)    0           ['concatenate_138[0][0]',
#                                                                   'conv2d_285[0][0]']
#
#  batch_normalization_286 (Batch  (None, 6, 6, 189)   756         ['concatenate_139[0][0]']
#  Normalization)
#
#  activation_277 (Activation)    (None, 6, 6, 189)    0           ['batch_normalization_286[0][0]']
#
#  conv2d_286 (Conv2D)            (None, 6, 6, 48)     9120        ['activation_277[0][0]']
#
#  batch_normalization_287 (Batch  (None, 6, 6, 48)    192         ['conv2d_286[0][0]']
#  Normalization)
#
#  activation_278 (Activation)    (None, 6, 6, 48)     0           ['batch_normalization_287[0][0]']
#
#  conv2d_287 (Conv2D)            (None, 6, 6, 12)     5196        ['activation_278[0][0]']
#
#  concatenate_140 (Concatenate)  (None, 6, 6, 201)    0           ['concatenate_139[0][0]',
#                                                                   'conv2d_287[0][0]']
#
#  batch_normalization_288 (Batch  (None, 6, 6, 201)   804         ['concatenate_140[0][0]']
#  Normalization)
#
#  activation_279 (Activation)    (None, 6, 6, 201)    0           ['batch_normalization_288[0][0]']
#
#  conv2d_288 (Conv2D)            (None, 6, 6, 48)     9696        ['activation_279[0][0]']
#
#  batch_normalization_289 (Batch  (None, 6, 6, 48)    192         ['conv2d_288[0][0]']
#  Normalization)
#
#  activation_280 (Activation)    (None, 6, 6, 48)     0           ['batch_normalization_289[0][0]']
#
#  conv2d_289 (Conv2D)            (None, 6, 6, 12)     5196        ['activation_280[0][0]']
#
#  concatenate_141 (Concatenate)  (None, 6, 6, 213)    0           ['concatenate_140[0][0]',
#                                                                   'conv2d_289[0][0]']
#
#  batch_normalization_290 (Batch  (None, 6, 6, 213)   852         ['concatenate_141[0][0]']
#  Normalization)
#
#  activation_281 (Activation)    (None, 6, 6, 213)    0           ['batch_normalization_290[0][0]']
#
#  conv2d_290 (Conv2D)            (None, 6, 6, 48)     10272       ['activation_281[0][0]']
#
#  batch_normalization_291 (Batch  (None, 6, 6, 48)    192         ['conv2d_290[0][0]']
#  Normalization)
#
#  activation_282 (Activation)    (None, 6, 6, 48)     0           ['batch_normalization_291[0][0]']
#
#  conv2d_291 (Conv2D)            (None, 6, 6, 12)     5196        ['activation_282[0][0]']
#
#  concatenate_142 (Concatenate)  (None, 6, 6, 225)    0           ['concatenate_141[0][0]',
#                                                                   'conv2d_291[0][0]']
#
#  batch_normalization_292 (Batch  (None, 6, 6, 225)   900         ['concatenate_142[0][0]']
#  Normalization)
#
#  activation_283 (Activation)    (None, 6, 6, 225)    0           ['batch_normalization_292[0][0]']
#
#  conv2d_292 (Conv2D)            (None, 6, 6, 48)     10848       ['activation_283[0][0]']
#
#  batch_normalization_293 (Batch  (None, 6, 6, 48)    192         ['conv2d_292[0][0]']
#  Normalization)
#
#  activation_284 (Activation)    (None, 6, 6, 48)     0           ['batch_normalization_293[0][0]']
#
#  conv2d_293 (Conv2D)            (None, 6, 6, 12)     5196        ['activation_284[0][0]']
#
#  concatenate_143 (Concatenate)  (None, 6, 6, 237)    0           ['concatenate_142[0][0]',
#                                                                   'conv2d_293[0][0]']
#
#  batch_normalization_294 (Batch  (None, 6, 6, 237)   948         ['concatenate_143[0][0]']
#  Normalization)
#
#  activation_285 (Activation)    (None, 6, 6, 237)    0           ['batch_normalization_294[0][0]']
#
#  conv2d_294 (Conv2D)            (None, 6, 6, 48)     11424       ['activation_285[0][0]']
#
#  batch_normalization_295 (Batch  (None, 6, 6, 48)    192         ['conv2d_294[0][0]']
#  Normalization)
#
#  activation_286 (Activation)    (None, 6, 6, 48)     0           ['batch_normalization_295[0][0]']
#
#  conv2d_295 (Conv2D)            (None, 6, 6, 12)     5196        ['activation_286[0][0]']
#
#  concatenate_144 (Concatenate)  (None, 6, 6, 249)    0           ['concatenate_143[0][0]',
#                                                                   'conv2d_295[0][0]']
#
#  batch_normalization_296 (Batch  (None, 6, 6, 249)   996         ['concatenate_144[0][0]']
#  Normalization)
#
#  activation_287 (Activation)    (None, 6, 6, 249)    0           ['batch_normalization_296[0][0]']
#
#  conv2d_296 (Conv2D)            (None, 6, 6, 48)     12000       ['activation_287[0][0]']
#
#  batch_normalization_297 (Batch  (None, 6, 6, 48)    192         ['conv2d_296[0][0]']
#  Normalization)
#
#  activation_288 (Activation)    (None, 6, 6, 48)     0           ['batch_normalization_297[0][0]']
#
#  conv2d_297 (Conv2D)            (None, 6, 6, 12)     5196        ['activation_288[0][0]']
#
#  concatenate_145 (Concatenate)  (None, 6, 6, 261)    0           ['concatenate_144[0][0]',
#                                                                   'conv2d_297[0][0]']
#
#  batch_normalization_298 (Batch  (None, 6, 6, 261)   1044        ['concatenate_145[0][0]']
#  Normalization)
#
#  activation_289 (Activation)    (None, 6, 6, 261)    0           ['batch_normalization_298[0][0]']
#
#  conv2d_298 (Conv2D)            (None, 6, 6, 48)     12576       ['activation_289[0][0]']
#
#  batch_normalization_299 (Batch  (None, 6, 6, 48)    192         ['conv2d_298[0][0]']
#  Normalization)
#
#  activation_290 (Activation)    (None, 6, 6, 48)     0           ['batch_normalization_299[0][0]']
#
#  conv2d_299 (Conv2D)            (None, 6, 6, 12)     5196        ['activation_290[0][0]']
#
#  concatenate_146 (Concatenate)  (None, 6, 6, 273)    0           ['concatenate_145[0][0]',
#                                                                   'conv2d_299[0][0]']
#
#  average_pooling2d_11 (AverageP  (None, 1, 1, 273)   0           ['concatenate_146[0][0]']
#  ooling2D)
#
#  flatten_2 (Flatten)            (None, 273)          0           ['average_pooling2d_11[0][0]']
#
#  dense_2 (Dense)                (None, 7)            1918        ['flatten_2[0][0]']
#
# ==================================================================================================
# Total params: 723,891
# Trainable params: 703,187
# Non-trainable params: 20,704
# __________________________________________________________________________________________________

# %% [markdown]
# ### Modelos ResNet utilizados

# %%
from tensorflow.keras.regularizers import l2

def resnet_layer(inputs, num_filters=16, kernel_size=3, strides=1,
                 activation='relu', batch_normalization=True, conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder"""
    conv = Conv2D(num_filters,
                  kernel_size =kernel_size,
                  strides     =strides,
                  padding     ='same',
                  kernel_initializer ='he_normal',
                  kernel_regularizer =l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %% [markdown]
# ## ResNet V1

# %%
batch_size = 64
epochs = 200
data_augmentation = True
n_clases = 7 #clases 
subtract_pixel_mean = True

n = 17  
depth = n * 6 + 2  # 104 capas

# Implementación ResNet V1
def resnet_v1(input_shape, depth, n_clases=7):
    """ResNet Version 1 Model"""
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (e.g. 20, 32, 44, 56, 110, 164)')
    
    # Empezar definición del modelo
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    
    # Instanciar la pila de unidades residuales
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # primera capa pero no primer stack
                strides = 2  # downsampling
            y = resnet_layer(inputs=x, num_filters=num_filters, strides=strides)
            y = resnet_layer(inputs=y, num_filters=num_filters, activation=None)
            
            if stack > 0 and res_block == 0:
                # proyección lineal de la conexión residual
                x = resnet_layer(inputs=x, num_filters=num_filters, kernel_size=1,
                                strides=strides, activation=None, batch_normalization=False)
            x = add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Añadir clasificador
    x = AveragePooling2D(pool_size=4)(x)  # Ajustado para tamaño 48x48
    y = Flatten()(x)
    outputs = Dense(n_clases, activation='softmax', kernel_initializer='he_normal')(y)

    # Instanciar modelo
    model = Model(inputs=inputs, outputs=outputs)
    return model
    # Definir la forma de la entrada (48x48x1 para imágenes en escala de grises)
input_shape = (48, 48, 1)
    
    # Crear modelo ResNet V2
model = resnet_v1(input_shape=input_shape, depth=depth, n_clases=n_clases)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 48, 48, 1)]  0           []
#
#  conv2d_157 (Conv2D)            (None, 48, 48, 16)   160         ['input_2[0][0]']
#
#  batch_normalization_154 (Batch  (None, 48, 48, 16)  64          ['conv2d_157[0][0]']
#  Normalization)
#
#  activation_154 (Activation)    (None, 48, 48, 16)   0           ['batch_normalization_154[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_154[0][0]']
#
#  batch_normalization_155 (Batch  (None, 48, 48, 16)  64          ['conv2d_158[0][0]']
#  Normalization)
#
#  activation_155 (Activation)    (None, 48, 48, 16)   0           ['batch_normalization_155[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_155[0][0]']
#
#  batch_normalization_156 (Batch  (None, 48, 48, 16)  64          ['conv2d_159[0][0]']
#  Normalization)
#
#  add_51 (Add)                   (None, 48, 48, 16)   0           ['activation_154[0][0]',
#                                                                   'batch_normalization_156[0][0]']
#
#  activation_156 (Activation)    (None, 48, 48, 16)   0           ['add_51[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_156[0][0]']
#
#  batch_normalization_157 (Batch  (None, 48, 48, 16)  64          ['conv2d_160[0][0]']
#  Normalization)
#
#  activation_157 (Activation)    (None, 48, 48, 16)   0           ['batch_normalization_157[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_157[0][0]']
#
#  batch_normalization_158 (Batch  (None, 48, 48, 16)  64          ['conv2d_161[0][0]']
#  Normalization)
#
#  add_52 (Add)                   (None, 48, 48, 16)   0           ['activation_156[0][0]',
#                                                                   'batch_normalization_158[0][0]']
#
#  activation_158 (Activation)    (None, 48, 48, 16)   0           ['add_52[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_158[0][0]']
#
#  batch_normalization_159 (Batch  (None, 48, 48, 16)  64          ['conv2d_162[0][0]']
#  Normalization)
#
#  activation_159 (Activation)    (None, 48, 48, 16)   0           ['batch_normalization_159[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_159[0][0]']
#
#  batch_normalization_160 (Batch  (None, 48, 48, 16)  64          ['conv2d_163[0][0]']
#  Normalization)
#
#  add_53 (Add)                   (None, 48, 48, 16)   0           ['activation_158[0][0]',
#                                                                   'batch_normalization_160[0][0]']
#
#  activation_160 (Activation)    (None, 48, 48, 16)   0           ['add_53[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_160[0][0]']
#
#  batch_normalization_161 (Batch  (None, 48, 48, 16)  64          ['conv2d_164[0][0]']
#  Normalization)
#
#  activation_161 (Activation)    (None, 48, 48, 16)   0           ['batch_normalization_161[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_161[0][0]']
#
#  batch_normalization_162 (Batch  (None, 48, 48, 16)  64          ['conv2d_165[0][0]']
#  Normalization)
#
#  add_54 (Add)                   (None, 48, 48, 16)   0           ['activation_160[0][0]',
#                                                                   'batch_normalization_162[0][0]']
#
#  activation_162 (Activation)    (None, 48, 48, 16)   0           ['add_54[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_162[0][0]']
#
#  batch_normalization_163 (Batch  (None, 48, 48, 16)  64          ['conv2d_166[0][0]']
#  Normalization)
#
#  activation_163 (Activation)    (None, 48, 48, 16)   0           ['batch_normalization_163[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_163[0][0]']
#
#  batch_normalization_164 (Batch  (None, 48, 48, 16)  64          ['conv2d_167[0][0]']
#  Normalization)
#
#  add_55 (Add)                   (None, 48, 48, 16)   0           ['activation_162[0][0]',
#                                                                   'batch_normalization_164[0][0]']
#
#  activation_164 (Activation)    (None, 48, 48, 16)   0           ['add_55[0][0]']
#
#  conv2d_168 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_164[0][0]']
#
#  batch_normalization_165 (Batch  (None, 48, 48, 16)  64          ['conv2d_168[0][0]']
#  Normalization)
#
#  activation_165 (Activation)    (None, 48, 48, 16)   0           ['batch_normalization_165[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_165[0][0]']
#
#  batch_normalization_166 (Batch  (None, 48, 48, 16)  64          ['conv2d_169[0][0]']
#  Normalization)
#
#  add_56 (Add)                   (None, 48, 48, 16)   0           ['activation_164[0][0]',
#                                                                   'batch_normalization_166[0][0]']
#
#  activation_166 (Activation)    (None, 48, 48, 16)   0           ['add_56[0][0]']
#
#  conv2d_170 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_166[0][0]']
#
#  batch_normalization_167 (Batch  (None, 48, 48, 16)  64          ['conv2d_170[0][0]']
#  Normalization)
#
#  activation_167 (Activation)    (None, 48, 48, 16)   0           ['batch_normalization_167[0][0]']
#
#  conv2d_171 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_167[0][0]']
#
#  batch_normalization_168 (Batch  (None, 48, 48, 16)  64          ['conv2d_171[0][0]']
#  Normalization)
#
#  add_57 (Add)                   (None, 48, 48, 16)   0           ['activation_166[0][0]',
#                                                                   'batch_normalization_168[0][0]']
#
#  activation_168 (Activation)    (None, 48, 48, 16)   0           ['add_57[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_168[0][0]']
#
#  batch_normalization_169 (Batch  (None, 48, 48, 16)  64          ['conv2d_172[0][0]']
#  Normalization)
#
#  activation_169 (Activation)    (None, 48, 48, 16)   0           ['batch_normalization_169[0][0]']
#
#  conv2d_173 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_169[0][0]']
#
#  batch_normalization_170 (Batch  (None, 48, 48, 16)  64          ['conv2d_173[0][0]']
#  Normalization)
#
#  add_58 (Add)                   (None, 48, 48, 16)   0           ['activation_168[0][0]',
#                                                                   'batch_normalization_170[0][0]']
#
#  activation_170 (Activation)    (None, 48, 48, 16)   0           ['add_58[0][0]']
#
#  conv2d_174 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_170[0][0]']
#
#  batch_normalization_171 (Batch  (None, 48, 48, 16)  64          ['conv2d_174[0][0]']
#  Normalization)
#
#  activation_171 (Activation)    (None, 48, 48, 16)   0           ['batch_normalization_171[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_171[0][0]']
#
#  batch_normalization_172 (Batch  (None, 48, 48, 16)  64          ['conv2d_175[0][0]']
#  Normalization)
#
#  add_59 (Add)                   (None, 48, 48, 16)   0           ['activation_170[0][0]',
#                                                                   'batch_normalization_172[0][0]']
#
#  activation_172 (Activation)    (None, 48, 48, 16)   0           ['add_59[0][0]']
#
#  conv2d_176 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_172[0][0]']
#
#  batch_normalization_173 (Batch  (None, 48, 48, 16)  64          ['conv2d_176[0][0]']
#  Normalization)
#
#  activation_173 (Activation)    (None, 48, 48, 16)   0           ['batch_normalization_173[0][0]']
#
#  conv2d_177 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_173[0][0]']
#
#  batch_normalization_174 (Batch  (None, 48, 48, 16)  64          ['conv2d_177[0][0]']
#  Normalization)
#
#  add_60 (Add)                   (None, 48, 48, 16)   0           ['activation_172[0][0]',
#                                                                   'batch_normalization_174[0][0]']
#
#  activation_174 (Activation)    (None, 48, 48, 16)   0           ['add_60[0][0]']
#
#  conv2d_178 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_174[0][0]']
#
#  batch_normalization_175 (Batch  (None, 48, 48, 16)  64          ['conv2d_178[0][0]']
#  Normalization)
#
#  activation_175 (Activation)    (None, 48, 48, 16)   0           ['batch_normalization_175[0][0]']
#
#  conv2d_179 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_175[0][0]']
#
#  batch_normalization_176 (Batch  (None, 48, 48, 16)  64          ['conv2d_179[0][0]']
#  Normalization)
#
#  add_61 (Add)                   (None, 48, 48, 16)   0           ['activation_174[0][0]',
#                                                                   'batch_normalization_176[0][0]']
#
#  activation_176 (Activation)    (None, 48, 48, 16)   0           ['add_61[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_176[0][0]']
#
#  batch_normalization_177 (Batch  (None, 48, 48, 16)  64          ['conv2d_180[0][0]']
#  Normalization)
#
#  activation_177 (Activation)    (None, 48, 48, 16)   0           ['batch_normalization_177[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_177[0][0]']
#
#  batch_normalization_178 (Batch  (None, 48, 48, 16)  64          ['conv2d_181[0][0]']
#  Normalization)
#
#  add_62 (Add)                   (None, 48, 48, 16)   0           ['activation_176[0][0]',
#                                                                   'batch_normalization_178[0][0]']
#
#  activation_178 (Activation)    (None, 48, 48, 16)   0           ['add_62[0][0]']
#
#  conv2d_182 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_178[0][0]']
#
#  batch_normalization_179 (Batch  (None, 48, 48, 16)  64          ['conv2d_182[0][0]']
#  Normalization)
#
#  activation_179 (Activation)    (None, 48, 48, 16)   0           ['batch_normalization_179[0][0]']
#
#  conv2d_183 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_179[0][0]']
#
#  batch_normalization_180 (Batch  (None, 48, 48, 16)  64          ['conv2d_183[0][0]']
#  Normalization)
#
#  add_63 (Add)                   (None, 48, 48, 16)   0           ['activation_178[0][0]',
#                                                                   'batch_normalization_180[0][0]']
#
#  activation_180 (Activation)    (None, 48, 48, 16)   0           ['add_63[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_180[0][0]']
#
#  batch_normalization_181 (Batch  (None, 48, 48, 16)  64          ['conv2d_184[0][0]']
#  Normalization)
#
#  activation_181 (Activation)    (None, 48, 48, 16)   0           ['batch_normalization_181[0][0]']
#
#  conv2d_185 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_181[0][0]']
#
#  batch_normalization_182 (Batch  (None, 48, 48, 16)  64          ['conv2d_185[0][0]']
#  Normalization)
#
#  add_64 (Add)                   (None, 48, 48, 16)   0           ['activation_180[0][0]',
#                                                                   'batch_normalization_182[0][0]']
#
#  activation_182 (Activation)    (None, 48, 48, 16)   0           ['add_64[0][0]']
#
#  conv2d_186 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_182[0][0]']
#
#  batch_normalization_183 (Batch  (None, 48, 48, 16)  64          ['conv2d_186[0][0]']
#  Normalization)
#
#  activation_183 (Activation)    (None, 48, 48, 16)   0           ['batch_normalization_183[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_183[0][0]']
#
#  batch_normalization_184 (Batch  (None, 48, 48, 16)  64          ['conv2d_187[0][0]']
#  Normalization)
#
#  add_65 (Add)                   (None, 48, 48, 16)   0           ['activation_182[0][0]',
#                                                                   'batch_normalization_184[0][0]']
#
#  activation_184 (Activation)    (None, 48, 48, 16)   0           ['add_65[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_184[0][0]']
#
#  batch_normalization_185 (Batch  (None, 48, 48, 16)  64          ['conv2d_188[0][0]']
#  Normalization)
#
#  activation_185 (Activation)    (None, 48, 48, 16)   0           ['batch_normalization_185[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_185[0][0]']
#
#  batch_normalization_186 (Batch  (None, 48, 48, 16)  64          ['conv2d_189[0][0]']
#  Normalization)
#
#  add_66 (Add)                   (None, 48, 48, 16)   0           ['activation_184[0][0]',
#                                                                   'batch_normalization_186[0][0]']
#
#  activation_186 (Activation)    (None, 48, 48, 16)   0           ['add_66[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_186[0][0]']
#
#  batch_normalization_187 (Batch  (None, 48, 48, 16)  64          ['conv2d_190[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 48, 48, 16)   0           ['batch_normalization_187[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 48, 48, 16)   2320        ['activation_187[0][0]']
#
#  batch_normalization_188 (Batch  (None, 48, 48, 16)  64          ['conv2d_191[0][0]']
#  Normalization)
#
#  add_67 (Add)                   (None, 48, 48, 16)   0           ['activation_186[0][0]',
#                                                                   'batch_normalization_188[0][0]']
#
#  activation_188 (Activation)    (None, 48, 48, 16)   0           ['add_67[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 24, 24, 32)   4640        ['activation_188[0][0]']
#
#  batch_normalization_189 (Batch  (None, 24, 24, 32)  128         ['conv2d_192[0][0]']
#  Normalization)
#
#  activation_189 (Activation)    (None, 24, 24, 32)   0           ['batch_normalization_189[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_189[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 24, 24, 32)   544         ['activation_188[0][0]']
#
#  batch_normalization_190 (Batch  (None, 24, 24, 32)  128         ['conv2d_193[0][0]']
#  Normalization)
#
#  add_68 (Add)                   (None, 24, 24, 32)   0           ['conv2d_194[0][0]',
#                                                                   'batch_normalization_190[0][0]']
#
#  activation_190 (Activation)    (None, 24, 24, 32)   0           ['add_68[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_190[0][0]']
#
#  batch_normalization_191 (Batch  (None, 24, 24, 32)  128         ['conv2d_195[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 24, 24, 32)   0           ['batch_normalization_191[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_191[0][0]']
#
#  batch_normalization_192 (Batch  (None, 24, 24, 32)  128         ['conv2d_196[0][0]']
#  Normalization)
#
#  add_69 (Add)                   (None, 24, 24, 32)   0           ['activation_190[0][0]',
#                                                                   'batch_normalization_192[0][0]']
#
#  activation_192 (Activation)    (None, 24, 24, 32)   0           ['add_69[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_192[0][0]']
#
#  batch_normalization_193 (Batch  (None, 24, 24, 32)  128         ['conv2d_197[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 24, 24, 32)   0           ['batch_normalization_193[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_193[0][0]']
#
#  batch_normalization_194 (Batch  (None, 24, 24, 32)  128         ['conv2d_198[0][0]']
#  Normalization)
#
#  add_70 (Add)                   (None, 24, 24, 32)   0           ['activation_192[0][0]',
#                                                                   'batch_normalization_194[0][0]']
#
#  activation_194 (Activation)    (None, 24, 24, 32)   0           ['add_70[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_194[0][0]']
#
#  batch_normalization_195 (Batch  (None, 24, 24, 32)  128         ['conv2d_199[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 24, 24, 32)   0           ['batch_normalization_195[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_195[0][0]']
#
#  batch_normalization_196 (Batch  (None, 24, 24, 32)  128         ['conv2d_200[0][0]']
#  Normalization)
#
#  add_71 (Add)                   (None, 24, 24, 32)   0           ['activation_194[0][0]',
#                                                                   'batch_normalization_196[0][0]']
#
#  activation_196 (Activation)    (None, 24, 24, 32)   0           ['add_71[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_196[0][0]']
#
#  batch_normalization_197 (Batch  (None, 24, 24, 32)  128         ['conv2d_201[0][0]']
#  Normalization)
#
#  activation_197 (Activation)    (None, 24, 24, 32)   0           ['batch_normalization_197[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_197[0][0]']
#
#  batch_normalization_198 (Batch  (None, 24, 24, 32)  128         ['conv2d_202[0][0]']
#  Normalization)
#
#  add_72 (Add)                   (None, 24, 24, 32)   0           ['activation_196[0][0]',
#                                                                   'batch_normalization_198[0][0]']
#
#  activation_198 (Activation)    (None, 24, 24, 32)   0           ['add_72[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_198[0][0]']
#
#  batch_normalization_199 (Batch  (None, 24, 24, 32)  128         ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_199 (Activation)    (None, 24, 24, 32)   0           ['batch_normalization_199[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_199[0][0]']
#
#  batch_normalization_200 (Batch  (None, 24, 24, 32)  128         ['conv2d_204[0][0]']
#  Normalization)
#
#  add_73 (Add)                   (None, 24, 24, 32)   0           ['activation_198[0][0]',
#                                                                   'batch_normalization_200[0][0]']
#
#  activation_200 (Activation)    (None, 24, 24, 32)   0           ['add_73[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_200[0][0]']
#
#  batch_normalization_201 (Batch  (None, 24, 24, 32)  128         ['conv2d_205[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 24, 24, 32)   0           ['batch_normalization_201[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_201[0][0]']
#
#  batch_normalization_202 (Batch  (None, 24, 24, 32)  128         ['conv2d_206[0][0]']
#  Normalization)
#
#  add_74 (Add)                   (None, 24, 24, 32)   0           ['activation_200[0][0]',
#                                                                   'batch_normalization_202[0][0]']
#
#  activation_202 (Activation)    (None, 24, 24, 32)   0           ['add_74[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_202[0][0]']
#
#  batch_normalization_203 (Batch  (None, 24, 24, 32)  128         ['conv2d_207[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 24, 24, 32)   0           ['batch_normalization_203[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_203[0][0]']
#
#  batch_normalization_204 (Batch  (None, 24, 24, 32)  128         ['conv2d_208[0][0]']
#  Normalization)
#
#  add_75 (Add)                   (None, 24, 24, 32)   0           ['activation_202[0][0]',
#                                                                   'batch_normalization_204[0][0]']
#
#  activation_204 (Activation)    (None, 24, 24, 32)   0           ['add_75[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_204[0][0]']
#
#  batch_normalization_205 (Batch  (None, 24, 24, 32)  128         ['conv2d_209[0][0]']
#  Normalization)
#
#  activation_205 (Activation)    (None, 24, 24, 32)   0           ['batch_normalization_205[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_205[0][0]']
#
#  batch_normalization_206 (Batch  (None, 24, 24, 32)  128         ['conv2d_210[0][0]']
#  Normalization)
#
#  add_76 (Add)                   (None, 24, 24, 32)   0           ['activation_204[0][0]',
#                                                                   'batch_normalization_206[0][0]']
#
#  activation_206 (Activation)    (None, 24, 24, 32)   0           ['add_76[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_206[0][0]']
#
#  batch_normalization_207 (Batch  (None, 24, 24, 32)  128         ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 24, 24, 32)   0           ['batch_normalization_207[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_207[0][0]']
#
#  batch_normalization_208 (Batch  (None, 24, 24, 32)  128         ['conv2d_212[0][0]']
#  Normalization)
#
#  add_77 (Add)                   (None, 24, 24, 32)   0           ['activation_206[0][0]',
#                                                                   'batch_normalization_208[0][0]']
#
#  activation_208 (Activation)    (None, 24, 24, 32)   0           ['add_77[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_208[0][0]']
#
#  batch_normalization_209 (Batch  (None, 24, 24, 32)  128         ['conv2d_213[0][0]']
#  Normalization)
#
#  activation_209 (Activation)    (None, 24, 24, 32)   0           ['batch_normalization_209[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 24, 24, 32)   9248        ['activation_209[0][0]']
#
#  batch_normalization_210 (Batch  (None, 24, 24, 32)  128         ['conv2d_214[0][0]']
#  Normalization)
# ...
#  batch_normalization_239 (Batch  (None, 12, 12, 64)  256         ['conv2d_244[0][0]']
#  Normalization)
#
#  activation_239 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_239[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_239[0][0]']
#
#  batch_normalization_240 (Batch  (None, 12, 12, 64)  256         ['conv2d_245[0][0]']
#  Normalization)
#
#  add_93 (Add)                   (None, 12, 12, 64)   0           ['activation_238[0][0]',
#                                                                   'batch_normalization_240[0][0]']
#
#  activation_240 (Activation)    (None, 12, 12, 64)   0           ['add_93[0][0]']
#
#  conv2d_246 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_240[0][0]']
#
#  batch_normalization_241 (Batch  (None, 12, 12, 64)  256         ['conv2d_246[0][0]']
#  Normalization)
#
#  activation_241 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_241[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_241[0][0]']
#
#  batch_normalization_242 (Batch  (None, 12, 12, 64)  256         ['conv2d_247[0][0]']
#  Normalization)
#
#  add_94 (Add)                   (None, 12, 12, 64)   0           ['activation_240[0][0]',
#                                                                   'batch_normalization_242[0][0]']
#
#  activation_242 (Activation)    (None, 12, 12, 64)   0           ['add_94[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_242[0][0]']
#
#  batch_normalization_243 (Batch  (None, 12, 12, 64)  256         ['conv2d_248[0][0]']
#  Normalization)
#
#  activation_243 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_243[0][0]']
#
#  conv2d_249 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_243[0][0]']
#
#  batch_normalization_244 (Batch  (None, 12, 12, 64)  256         ['conv2d_249[0][0]']
#  Normalization)
#
#  add_95 (Add)                   (None, 12, 12, 64)   0           ['activation_242[0][0]',
#                                                                   'batch_normalization_244[0][0]']
#
#  activation_244 (Activation)    (None, 12, 12, 64)   0           ['add_95[0][0]']
#
#  conv2d_250 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_244[0][0]']
#
#  batch_normalization_245 (Batch  (None, 12, 12, 64)  256         ['conv2d_250[0][0]']
#  Normalization)
#
#  activation_245 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_245[0][0]']
#
#  conv2d_251 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_245[0][0]']
#
#  batch_normalization_246 (Batch  (None, 12, 12, 64)  256         ['conv2d_251[0][0]']
#  Normalization)
#
#  add_96 (Add)                   (None, 12, 12, 64)   0           ['activation_244[0][0]',
#                                                                   'batch_normalization_246[0][0]']
#
#  activation_246 (Activation)    (None, 12, 12, 64)   0           ['add_96[0][0]']
#
#  conv2d_252 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_246[0][0]']
#
#  batch_normalization_247 (Batch  (None, 12, 12, 64)  256         ['conv2d_252[0][0]']
#  Normalization)
#
#  activation_247 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_247[0][0]']
#
#  conv2d_253 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_247[0][0]']
#
#  batch_normalization_248 (Batch  (None, 12, 12, 64)  256         ['conv2d_253[0][0]']
#  Normalization)
#
#  add_97 (Add)                   (None, 12, 12, 64)   0           ['activation_246[0][0]',
#                                                                   'batch_normalization_248[0][0]']
#
#  activation_248 (Activation)    (None, 12, 12, 64)   0           ['add_97[0][0]']
#
#  conv2d_254 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_248[0][0]']
#
#  batch_normalization_249 (Batch  (None, 12, 12, 64)  256         ['conv2d_254[0][0]']
#  Normalization)
#
#  activation_249 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_249[0][0]']
#
#  conv2d_255 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_249[0][0]']
#
#  batch_normalization_250 (Batch  (None, 12, 12, 64)  256         ['conv2d_255[0][0]']
#  Normalization)
#
#  add_98 (Add)                   (None, 12, 12, 64)   0           ['activation_248[0][0]',
#                                                                   'batch_normalization_250[0][0]']
#
#  activation_250 (Activation)    (None, 12, 12, 64)   0           ['add_98[0][0]']
#
#  conv2d_256 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_250[0][0]']
#
#  batch_normalization_251 (Batch  (None, 12, 12, 64)  256         ['conv2d_256[0][0]']
#  Normalization)
#
#  activation_251 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_251[0][0]']
#
#  conv2d_257 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_251[0][0]']
#
#  batch_normalization_252 (Batch  (None, 12, 12, 64)  256         ['conv2d_257[0][0]']
#  Normalization)
#
#  add_99 (Add)                   (None, 12, 12, 64)   0           ['activation_250[0][0]',
#                                                                   'batch_normalization_252[0][0]']
#
#  activation_252 (Activation)    (None, 12, 12, 64)   0           ['add_99[0][0]']
#
#  conv2d_258 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_252[0][0]']
#
#  batch_normalization_253 (Batch  (None, 12, 12, 64)  256         ['conv2d_258[0][0]']
#  Normalization)
#
#  activation_253 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_253[0][0]']
#
#  conv2d_259 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_253[0][0]']
#
#  batch_normalization_254 (Batch  (None, 12, 12, 64)  256         ['conv2d_259[0][0]']
#  Normalization)
#
#  add_100 (Add)                  (None, 12, 12, 64)   0           ['activation_252[0][0]',
#                                                                   'batch_normalization_254[0][0]']
#
#  activation_254 (Activation)    (None, 12, 12, 64)   0           ['add_100[0][0]']
#
#  conv2d_260 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_254[0][0]']
#
#  batch_normalization_255 (Batch  (None, 12, 12, 64)  256         ['conv2d_260[0][0]']
#  Normalization)
#
#  activation_255 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_255[0][0]']
#
#  conv2d_261 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_255[0][0]']
#
#  batch_normalization_256 (Batch  (None, 12, 12, 64)  256         ['conv2d_261[0][0]']
#  Normalization)
#
#  add_101 (Add)                  (None, 12, 12, 64)   0           ['activation_254[0][0]',
#                                                                   'batch_normalization_256[0][0]']
#
#  activation_256 (Activation)    (None, 12, 12, 64)   0           ['add_101[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 3, 3, 64)    0           ['activation_256[0][0]']
#  oling2D)
#
#  flatten_1 (Flatten)            (None, 576)          0           ['average_pooling2d_1[0][0]']
#
#  dense_1 (Dense)                (None, 7)            4039        ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 1,647,975
# Trainable params: 1,640,327
# Non-trainable params: 7,648
# __________________________________________________________________________________________________

# %% [markdown]
# ## ResNet V2

# %%
batch_size = 64
epochs = 200
data_augmentation = True
n_clases = 7 #clases 
subtract_pixel_mean = True #Mejora accuracy

# Para ResNet V2, la profundidad se calcula diferente
n = 17
depth = n * 9 + 2  # 155 capas
# Implementación ResNet V2
def resnet_v2(input_shape, depth, n_clases=7):
    """ResNet Version 2 Model con pre-activación"""
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (e.g. 29, 47, 56, 92, 110, 164)')
    
    #definición del modelo
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    
    # v2 realiza Conv2D con BN-ReLU en la entrada antes de dividirse en caminos
    x = resnet_layer(inputs=inputs)
    
    for stack in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stack == 0:
                # Primer stage mantiene resolución, duplica filtros
                num_filters_out = num_filters_in * 4
                # Primera capa y primer stage
                if res_block == 0:  
                    activation = None
                    batch_normalization = False
            else:
                # Otros stages reducen resolución, duplican filtros
                num_filters_out = num_filters_in * 2
                # Primera capa pero no primer stage
                if res_block == 0:
                    # downsample
                    strides = 2
            
            # Bloque residual con pre-activación (BN-ReLU-Conv)
            y = resnet_layer(inputs=x,num_filters=num_filters_in,kernel_size=1,strides=strides,
                             activation=activation,batch_normalization=batch_normalization,conv_first=False)# Primera parte del bloque
            y = resnet_layer(inputs=y,num_filters=num_filters_in,conv_first=False)# Segunda parte 
            y = resnet_layer(inputs=y,num_filters=num_filters_out,kernel_size=1,conv_first=False)# Tercera parte 
            # Proyección de la conexión residual si cambia dimensiones
            if res_block == 0:
                # Proyección lineal para ajustar dimensiones
                x = resnet_layer(inputs=x,num_filters=num_filters_out,kernel_size=1,
                    strides=strides,activation=None,batch_normalization=False)
            
            x = add([x, y])
        
        num_filters_in = num_filters_out
    
    # En ResNet V2, BN-ReLU antes del Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # Añadir clasificador
    x = AveragePooling2D(pool_size=4)(x)  # Ajustado para tamaño 48x48
    y = Flatten()(x)
    outputs = Dense(n_clases, activation='softmax', kernel_initializer='he_normal')(y)

    #Intalación del modelo
    model = Model(inputs=inputs, outputs=outputs)
    return model


    
    # Definir la forma de la entrada (48x48x1 para imágenes en escala de grises)
input_shape = (48, 48, 1)
    
    # Crear modelo ResNet V2
model = resnet_v2(input_shape=input_shape, depth=depth, n_clases=n_clases)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 48, 48, 16)   160         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 48, 48, 16)  64          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 48, 48, 16)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 48, 48, 16)   272         ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 48, 48, 16)  64          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 48, 48, 16)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 48, 48, 16)   2320        ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 48, 48, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 48, 48, 16)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 48, 48, 64)   1088        ['activation[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 48, 48, 64)   1088        ['activation_2[0][0]']
#
#  add (Add)                      (None, 48, 48, 64)   0           ['conv2d_4[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 48, 48, 64)  256         ['add[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 48, 48, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 48, 48, 16)   1040        ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 48, 48, 16)  64          ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 48, 48, 16)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 48, 48, 16)   2320        ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 48, 48, 16)  64          ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 48, 48, 16)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 48, 48, 64)   1088        ['activation_5[0][0]']
#
#  add_1 (Add)                    (None, 48, 48, 64)   0           ['add[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 48, 48, 64)  256         ['add_1[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 48, 48, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 48, 48, 16)   1040        ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 48, 48, 16)  64          ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 48, 48, 16)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 48, 48, 16)   2320        ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 48, 48, 16)  64          ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 48, 48, 16)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 48, 48, 64)   1088        ['activation_8[0][0]']
#
#  add_2 (Add)                    (None, 48, 48, 64)   0           ['add_1[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 48, 48, 64)  256         ['add_2[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 48, 48, 64)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 48, 48, 16)   1040        ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 48, 48, 16)  64          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 48, 48, 16)   2320        ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 48, 48, 16)  64          ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 48, 48, 64)   1088        ['activation_11[0][0]']
#
#  add_3 (Add)                    (None, 48, 48, 64)   0           ['add_2[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 48, 48, 64)  256         ['add_3[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 48, 48, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 48, 48, 16)   1040        ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 48, 48, 16)  64          ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 48, 48, 16)   2320        ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 48, 48, 16)  64          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 48, 48, 64)   1088        ['activation_14[0][0]']
#
#  add_4 (Add)                    (None, 48, 48, 64)   0           ['add_3[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 48, 48, 64)  256         ['add_4[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 48, 48, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 48, 48, 16)   1040        ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 48, 48, 16)  64          ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 48, 48, 16)   2320        ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 48, 48, 16)  64          ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 48, 48, 64)   1088        ['activation_17[0][0]']
#
#  add_5 (Add)                    (None, 48, 48, 64)   0           ['add_4[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 48, 48, 64)  256         ['add_5[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 48, 48, 64)   0           ['batch_normalization_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 48, 48, 16)   1040        ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 48, 48, 16)  64          ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 48, 48, 16)   2320        ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 48, 48, 16)  64          ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 48, 48, 64)   1088        ['activation_20[0][0]']
#
#  add_6 (Add)                    (None, 48, 48, 64)   0           ['add_5[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 48, 48, 64)  256         ['add_6[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 48, 48, 64)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 48, 48, 16)   1040        ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 48, 48, 16)  64          ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 48, 48, 16)   2320        ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 48, 48, 16)  64          ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 48, 48, 64)   1088        ['activation_23[0][0]']
#
#  add_7 (Add)                    (None, 48, 48, 64)   0           ['add_6[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 48, 48, 64)  256         ['add_7[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 48, 48, 64)   0           ['batch_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 48, 48, 16)   1040        ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 48, 48, 16)  64          ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 48, 48, 16)   2320        ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 48, 48, 16)  64          ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_26[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 48, 48, 64)   1088        ['activation_26[0][0]']
#
#  add_8 (Add)                    (None, 48, 48, 64)   0           ['add_7[0][0]',
#                                                                   'conv2d_28[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 48, 48, 64)  256         ['add_8[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 48, 48, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 48, 48, 16)   1040        ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 48, 48, 16)  64          ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 48, 48, 16)   2320        ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 48, 48, 16)  64          ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 48, 48, 64)   1088        ['activation_29[0][0]']
#
#  add_9 (Add)                    (None, 48, 48, 64)   0           ['add_8[0][0]',
#                                                                   'conv2d_31[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 48, 48, 64)  256         ['add_9[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 48, 48, 64)   0           ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 48, 48, 16)   1040        ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 48, 48, 16)  64          ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 48, 48, 16)   2320        ['activation_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 48, 48, 16)  64          ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_32[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 48, 48, 64)   1088        ['activation_32[0][0]']
#
#  add_10 (Add)                   (None, 48, 48, 64)   0           ['add_9[0][0]',
#                                                                   'conv2d_34[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 48, 48, 64)  256         ['add_10[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 48, 48, 64)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 48, 48, 16)   1040        ['activation_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 48, 48, 16)  64          ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 48, 48, 16)   2320        ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 48, 48, 16)  64          ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 48, 48, 64)   1088        ['activation_35[0][0]']
#
#  add_11 (Add)                   (None, 48, 48, 64)   0           ['add_10[0][0]',
#                                                                   'conv2d_37[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 48, 48, 64)  256         ['add_11[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 48, 48, 64)   0           ['batch_normalization_36[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 48, 48, 16)   1040        ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 48, 48, 16)  64          ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 48, 48, 16)   2320        ['activation_37[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 48, 48, 16)  64          ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_38[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 48, 48, 64)   1088        ['activation_38[0][0]']
#
#  add_12 (Add)                   (None, 48, 48, 64)   0           ['add_11[0][0]',
#                                                                   'conv2d_40[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 48, 48, 64)  256         ['add_12[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 48, 48, 64)   0           ['batch_normalization_39[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 48, 48, 16)   1040        ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 48, 48, 16)  64          ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_40[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 48, 48, 16)   2320        ['activation_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 48, 48, 16)  64          ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 48, 48, 64)   1088        ['activation_41[0][0]']
#
#  add_13 (Add)                   (None, 48, 48, 64)   0           ['add_12[0][0]',
#                                                                   'conv2d_43[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 48, 48, 64)  256         ['add_13[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 48, 48, 64)   0           ['batch_normalization_42[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 48, 48, 16)   1040        ['activation_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 48, 48, 16)  64          ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_43[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 48, 48, 16)   2320        ['activation_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 48, 48, 16)  64          ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_44[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 48, 48, 64)   1088        ['activation_44[0][0]']
#
#  add_14 (Add)                   (None, 48, 48, 64)   0           ['add_13[0][0]',
#                                                                   'conv2d_46[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 48, 48, 64)  256         ['add_14[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 48, 48, 64)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 48, 48, 16)   1040        ['activation_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 48, 48, 16)  64          ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_46[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 48, 48, 16)   2320        ['activation_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 48, 48, 16)  64          ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 48, 48, 64)   1088        ['activation_47[0][0]']
#
#  add_15 (Add)                   (None, 48, 48, 64)   0           ['add_14[0][0]',
#                                                                   'conv2d_49[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 48, 48, 64)  256         ['add_15[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 48, 48, 64)   0           ['batch_normalization_48[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 48, 48, 16)   1040        ['activation_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 48, 48, 16)  64          ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_49[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 48, 48, 16)   2320        ['activation_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 48, 48, 16)  64          ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 48, 48, 16)   0           ['batch_normalization_50[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 48, 48, 64)   1088        ['activation_50[0][0]']
#
#  add_16 (Add)                   (None, 48, 48, 64)   0           ['add_15[0][0]',
#                                                                   'conv2d_52[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 48, 48, 64)  256         ['add_16[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 48, 48, 64)   0           ['batch_normalization_51[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 24, 24, 64)   4160        ['activation_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 24, 24, 64)  256         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 24, 24, 64)   0           ['batch_normalization_52[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 24, 24, 64)   36928       ['activation_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 24, 24, 64)  256         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 24, 24, 64)   0           ['batch_normalization_53[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 24, 24, 128)  8320        ['add_16[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 24, 24, 128)  8320        ['activation_53[0][0]']
#
#  add_17 (Add)                   (None, 24, 24, 128)  0           ['conv2d_56[0][0]',
#                                                                   'conv2d_55[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 24, 24, 128)  512        ['add_17[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 24, 24, 128)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 24, 24, 64)   8256        ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 24, 24, 64)  256         ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 24, 24, 64)   0           ['batch_normalization_55[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 24, 24, 64)   36928       ['activation_55[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 24, 24, 64)  256         ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 24, 24, 64)   0           ['batch_normalization_56[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 24, 24, 128)  8320        ['activation_56[0][0]']
#
#  add_18 (Add)                   (None, 24, 24, 128)  0           ['add_17[0][0]',
#                                                                   'conv2d_59[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 24, 24, 128)  512        ['add_18[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 24, 24, 128)  0           ['batch_normalization_57[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 24, 24, 64)   8256        ['activation_57[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 24, 24, 64)  256         ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 24, 24, 64)   0           ['batch_normalization_58[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 24, 24, 64)   36928       ['activation_58[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 24, 24, 64)  256         ['conv2d_61[0][0]']
#  ormalization)
#
# ...
#                                                                   'conv2d_138[0][0]']
#
#  batch_normalization_135 (Batch  (None, 12, 12, 256)  1024       ['add_44[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (None, 12, 12, 256)  0           ['batch_normalization_135[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 12, 12, 128)  32896       ['activation_135[0][0]']
#
#  batch_normalization_136 (Batch  (None, 12, 12, 128)  512        ['conv2d_139[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_136[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 12, 12, 128)  147584      ['activation_136[0][0]']
#
#  batch_normalization_137 (Batch  (None, 12, 12, 128)  512        ['conv2d_140[0][0]']
#  Normalization)
#
#  activation_137 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_137[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 12, 12, 256)  33024       ['activation_137[0][0]']
#
#  add_45 (Add)                   (None, 12, 12, 256)  0           ['add_44[0][0]',
#                                                                   'conv2d_141[0][0]']
#
#  batch_normalization_138 (Batch  (None, 12, 12, 256)  1024       ['add_45[0][0]']
#  Normalization)
#
#  activation_138 (Activation)    (None, 12, 12, 256)  0           ['batch_normalization_138[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 12, 12, 128)  32896       ['activation_138[0][0]']
#
#  batch_normalization_139 (Batch  (None, 12, 12, 128)  512        ['conv2d_142[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_139[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 12, 12, 128)  147584      ['activation_139[0][0]']
#
#  batch_normalization_140 (Batch  (None, 12, 12, 128)  512        ['conv2d_143[0][0]']
#  Normalization)
#
#  activation_140 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_140[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 12, 12, 256)  33024       ['activation_140[0][0]']
#
#  add_46 (Add)                   (None, 12, 12, 256)  0           ['add_45[0][0]',
#                                                                   'conv2d_144[0][0]']
#
#  batch_normalization_141 (Batch  (None, 12, 12, 256)  1024       ['add_46[0][0]']
#  Normalization)
#
#  activation_141 (Activation)    (None, 12, 12, 256)  0           ['batch_normalization_141[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 12, 12, 128)  32896       ['activation_141[0][0]']
#
#  batch_normalization_142 (Batch  (None, 12, 12, 128)  512        ['conv2d_145[0][0]']
#  Normalization)
#
#  activation_142 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_142[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 12, 12, 128)  147584      ['activation_142[0][0]']
#
#  batch_normalization_143 (Batch  (None, 12, 12, 128)  512        ['conv2d_146[0][0]']
#  Normalization)
#
#  activation_143 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_143[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 12, 12, 256)  33024       ['activation_143[0][0]']
#
#  add_47 (Add)                   (None, 12, 12, 256)  0           ['add_46[0][0]',
#                                                                   'conv2d_147[0][0]']
#
#  batch_normalization_144 (Batch  (None, 12, 12, 256)  1024       ['add_47[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 12, 12, 256)  0           ['batch_normalization_144[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 12, 12, 128)  32896       ['activation_144[0][0]']
#
#  batch_normalization_145 (Batch  (None, 12, 12, 128)  512        ['conv2d_148[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_145[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 12, 12, 128)  147584      ['activation_145[0][0]']
#
#  batch_normalization_146 (Batch  (None, 12, 12, 128)  512        ['conv2d_149[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_146[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 12, 12, 256)  33024       ['activation_146[0][0]']
#
#  add_48 (Add)                   (None, 12, 12, 256)  0           ['add_47[0][0]',
#                                                                   'conv2d_150[0][0]']
#
#  batch_normalization_147 (Batch  (None, 12, 12, 256)  1024       ['add_48[0][0]']
#  Normalization)
#
#  activation_147 (Activation)    (None, 12, 12, 256)  0           ['batch_normalization_147[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 12, 12, 128)  32896       ['activation_147[0][0]']
#
#  batch_normalization_148 (Batch  (None, 12, 12, 128)  512        ['conv2d_151[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_148[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 12, 12, 128)  147584      ['activation_148[0][0]']
#
#  batch_normalization_149 (Batch  (None, 12, 12, 128)  512        ['conv2d_152[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_149[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 12, 12, 256)  33024       ['activation_149[0][0]']
#
#  add_49 (Add)                   (None, 12, 12, 256)  0           ['add_48[0][0]',
#                                                                   'conv2d_153[0][0]']
#
#  batch_normalization_150 (Batch  (None, 12, 12, 256)  1024       ['add_49[0][0]']
#  Normalization)
#
#  activation_150 (Activation)    (None, 12, 12, 256)  0           ['batch_normalization_150[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 12, 12, 128)  32896       ['activation_150[0][0]']
#
#  batch_normalization_151 (Batch  (None, 12, 12, 128)  512        ['conv2d_154[0][0]']
#  Normalization)
#
#  activation_151 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_151[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 12, 12, 128)  147584      ['activation_151[0][0]']
#
#  batch_normalization_152 (Batch  (None, 12, 12, 128)  512        ['conv2d_155[0][0]']
#  Normalization)
#
#  activation_152 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_152[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 12, 12, 256)  33024       ['activation_152[0][0]']
#
#  add_50 (Add)                   (None, 12, 12, 256)  0           ['add_49[0][0]',
#                                                                   'conv2d_156[0][0]']
#
#  batch_normalization_153 (Batch  (None, 12, 12, 256)  1024       ['add_50[0][0]']
#  Normalization)
#
#  activation_153 (Activation)    (None, 12, 12, 256)  0           ['batch_normalization_153[0][0]']
#
#  average_pooling2d (AveragePool  (None, 3, 3, 256)   0           ['activation_153[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 2304)         0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 7)            16135       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 4,711,047
# Trainable params: 4,681,639
# Non-trainable params: 29,408
# __________________________________________________________________________________________________

# %% [markdown]
# ### Se testean los mejores modelos obtenidos tras el entrenamiento en KHIPU
#
# ## DenseNet 0.3

# %%
from tensorflow.keras.models import load_model

# Cargar el modelo
model_03 = load_model('saved_models_200_epocas_0.3_compression_factor\FER2013_densenet_model_compression_factor_0.3.84.h5')

X_train, X_test, y_train, y_test = extraer_imagenes("FER")

# Evaluar
loss, accuracy = model_03.evaluate(X_test, y_test)
print(f"Test accuracy: {accuracy:.4f}")
# Out:
# 225/225 [==============================] - 32s 136ms/step - loss: 1.1375 - acc: 0.6828
# Test accuracy: 0.6828

# %% [markdown]
# ## DenseNet 0.5

# %%
# Cargar el modelo
model_05 = load_model('saved_models_200_epocas_0.5_compression_factor\FER2013_densenet_model_compression_factor_0.5.106.h5')

# Evaluar
loss, accuracy = model_05.evaluate(X_test, y_test)
print(f"Test accuracy: {accuracy:.4f}")
# Out:
# 225/225 [==============================] - 33s 140ms/step - loss: 1.8759 - acc: 0.6909
# Test accuracy: 0.6909

# %% [markdown]
# ## DenseNet 0.7

# %%
# Cargar el modelo
model_07 = load_model('saved_models_200_epocas_0.7_compression_factor\FER2013_densenet_model_compression_factor_0.7.92.h5')

# Evaluar
loss, accuracy = model_07.evaluate(X_test, y_test)
print(f"Test accuracy: {accuracy:.4f}")
# Out:
# 225/225 [==============================] - 35s 149ms/step - loss: 1.2770 - acc: 0.6934
# Test accuracy: 0.6934

# %% [markdown]
# ## ResNet V1

# %%
# Cargar el modelo
model_v1 = load_model("saved_models/fer2013_resnet104v1.h5")

# Evaluar
loss, accuracy = model_v1.evaluate(X_test, y_test)
print(f"Test accuracy: {accuracy:.4f}")
# Out:
# 225/225 [==============================] - 23s 93ms/step - loss: 1.9426 - accuracy: 0.6652
# Test accuracy: 0.6652

# %% [markdown]
# ## ResNet V2

# %%
# Cargar el modelo
model_v2 = load_model('saved_models/fer2013_resnet155v2.h5')

# Evaluar
loss, accuracy = model_v2.evaluate(X_test, y_test)
print(f"Test accuracy: {accuracy:.4f}")
# Out:
# 225/225 [==============================] - 34s 142ms/step - loss: 1.4614 - accuracy: 0.6627
# Test accuracy: 0.6627
